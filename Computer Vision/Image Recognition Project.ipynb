# %% [markdown]
# # Image Recognition Project

# %% [markdown]
# ### The purpose is to test the ability of the program to recognize both human and AI generated faces.
#
# 3 tests were performed.
#
# 1) World Leaders
# 2) Sam Altman (CEO of Open AI)
# 3) Disney Princesses
#
# <br>
# Results:
# <br>
# 1) World Leaders: Only 3 faces were identified.
# <br>
# 2) Sam Altman (CEO of Open AI): Identified.
# <br>
# 3) Disney Princesses: All identified.
# <br>

# %%
import PIL.Image
import PIL.ImageDraw

import face_recognition

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Read Image
img = mpimg.imread('WorldLeaders.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('WorldLeaders.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="red",width=3)

# Display the image on screen
pil_image.show()
# Out:
# I found 3 face(s) in this photograph.
# A face is located at pixel location Top: 67, Left: 296, Bottom: 118, Right: 348
# A face is located at pixel location Top: 101, Left: 43, Bottom: 153, Right: 95
# A face is located at pixel location Top: 132, Left: 578, Bottom: 175, Right: 621

# %%
# Read Image
img = mpimg.imread('Result.jpg')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('Altman.jpg')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('Altman.jpg')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="red",width=3)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 99, Left: 526, Bottom: 420, Right: 847

# %%
# Read Image
img = mpimg.imread('Result2.jpg')
 
# Output Image
plt.imshow(img)

# %% [markdown]
# ### Source for Disney Princesses (below)
#
# ### https://www.reddit.com/r/midjourney/comments/13ko8yc/disney_princesses_and_nonprincesses_reimagined_as/?utm_source=superhuman.beehiiv.com&utm_medium=newsletter&utm_campaign=stability-ai-unleashes-a-new-era-of-ai-interfaces-with-stablestudio

# %%
# Read Image 
img = mpimg.imread('DisneyPrincess.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('DisneyPrincess.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="red",width=3)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 80, Left: 212, Bottom: 155, Right: 287

# %%
# Read Image 
img = mpimg.imread('DP.jpg')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('DisneyPrincess1.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('DisneyPrincess1.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="red",width=3)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 46, Left: 218, Bottom: 108, Right: 280

# %%
# Read Image 
img = mpimg.imread('DP1.jpg')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('DisneyPrincess2.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('DisneyPrincess2.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="red",width=3)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 86, Left: 185, Bottom: 176, Right: 275

# %%
# Read Image 
img = mpimg.imread('DP2.jpg')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('DisneyPrincess3.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('DisneyPrincess3.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="red",width=3)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 116, Left: 199, Bottom: 223, Right: 306

# %%
# Read Image 
img = mpimg.imread('DP3.jpg')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('DisneyPrincess4.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('DisneyPrincess4.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="red",width=3)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 180, Left: 655, Bottom: 366, Right: 840

# %%
# Read Image 
img = mpimg.imread('DP4.jpg')
 
# Output Image
plt.imshow(img)
